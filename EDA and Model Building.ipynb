# %% [markdown]
# # About Dataset
#
# The Diabetes prediction dataset is a collection of medical and demographic data from patients, along with their diabetes status (positive or negative). The data includes features such as age, gender, body mass index (BMI), hypertension, heart disease, smoking history, HbA1c level, and blood glucose level. This dataset can be used to build machine learning models to predict diabetes in patients based on their medical history and demographic information. This can be useful for healthcare professionals in identifying patients who may be at risk of developing diabetes and in developing personalized treatment plans. Additionally, the dataset can be used by researchers to explore the relationships between various medical and demographic factors and the likelihood of developing diabetes.

# %%
# import libreary

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# display all the columns are datasets

pd.pandas.set_option("display.max_columns", None)

# %%
# import dataset

df = pd.read_csv(r'C:\Users\Mukul\Downloads\diabetes_prediction_dataset.csv')

# %%
# check top five rows
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
# check the last five rows
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
# check the columns
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
# check the shape of dataset
df.shape
# Out:
# (100000, 9)

# %%
# check the information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
# check the data type
df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
# check the size of dataset
df.size
# Out:
# 900000

# %%
# check the missing value
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
# check the null value 
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# it is indicated the no null value

# %%
# check the unique value

df.nunique()
# Out:
# gender                    3
# age                     102
# hypertension              2
# heart_disease             2
# smoking_history           6
# bmi                    4247
# HbA1c_level              18
# blood_glucose_level      18
# diabetes                  2
# dtype: int64

# %%
# check the sort value of unique value
df.nunique().sort_values(ascending=False)
# Out:
# bmi                    4247
# age                     102
# HbA1c_level              18
# blood_glucose_level      18
# smoking_history           6
# gender                    3
# hypertension              2
# heart_disease             2
# diabetes                  2
# dtype: int64

# %%
# check the unique value in graph

df.nunique().plot.bar(figsize=(12,10))
plt.xlabel('Variable')
plt.ylabel('Number of Unique Value')
plt.title(' Number  of missing value ')
# Out:
# Text(0.5, 1.0, ' Number  of missing value ')

# %%
# check the dupliacted values 
df.duplicated().sum()
# Out:
# 3854

# %%
# it is indicated the duplicated value
df[df.duplicated()]
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 2756     Male  80.0             0              0         No Info  27.32
# 3272   Female  80.0             0              0         No Info  27.32
# 3418   Female  19.0             0              0         No Info  27.32
# 3939   Female  78.0             1              0          former  27.32
# 3960     Male  47.0             0              0         No Info  27.32
# ...       ...   ...           ...            ...             ...    ...
# 99980  Female  52.0             0              0           never  27.32
# 99985    Male  25.0             0              0         No Info  27.32
# 99989  Female  26.0             0              0         No Info  27.32
# 99990    Male  39.0             0              0         No Info  27.32
# 99995  Female  80.0             0              0         No Info  27.32
#
#        HbA1c_level  blood_glucose_level  diabetes
# 2756           6.6                  159         0
# ...

# %%
# drop the duplicated values

df = df.drop_duplicates()

# %%
# again check the duplicated value

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# it is indicated no duplicated value

# %%
# getting the counnt of each category of data

for feature in df.columns:
    print(df[feature].value_counts())
# Out:
# Female    56161
# Male      39967
# Other        18
# Name: gender, dtype: int64
# 80.00    4932
# 51.00    1566
# 47.00    1511
# 48.00    1508
# 53.00    1498
#          ...
# 0.48       83
# 1.00       83
# 0.40       66
# 0.16       59
# 0.08       36
# Name: age, Length: 102, dtype: int64
# 0    88685
# 1     7461
# Name: hypertension, dtype: int64
# 0    92223
# 1     3923
# Name: heart_disease, dtype: int64
# never          34398
# No Info        32887
# former          9299
# current         9197
# not current     6367
# ever            3998
# Name: smoking_history, dtype: int64
# 27.32    21666
# 23.00      103
# 27.12      101
# 24.96      100
# 27.80      100
#          ...
# 58.23        1
# 48.18        1
# 55.57        1
# 57.07        1
# 60.52        1
# Name: bmi, Length: 4247, dtype: int64
# 6.6    8164
# 5.7    8124
# 6.5    8051
# 5.8    7992
# 6.0    7988
# 6.2    7958
# 6.1    7716
# 3.5    7319
# 4.8    7296
# 4.5    7290
# 4.0    7205
# 5.0    7155
# ...

# %%
# check the each category of unique value

for feature in df.columns:
    print(df[feature].unique())
# Out:
# ['Female' 'Male' 'Other']
# [80.   54.   28.   36.   76.   20.   44.   79.   42.   32.   53.   78.
#  67.   15.   37.   40.    5.   69.   72.    4.   30.   45.   43.   50.
#  41.   26.   34.   73.   77.   66.   29.   60.   38.    3.   57.   74.
#  19.   46.   21.   59.   27.   13.   56.    2.    7.   11.    6.   55.
#   9.   62.   47.   12.   68.   75.   22.   58.   18.   24.   17.   25.
#   0.08 33.   16.   61.   31.    8.   49.   39.   65.   14.   70.    0.56
#  48.   51.   71.    0.88 64.   63.   52.    0.16 10.   35.   23.    0.64
#   1.16  1.64  0.72  1.88  1.32  0.8   1.24  1.    1.8   0.48  1.56  1.08
#   0.24  1.4   0.4   0.32  1.72  1.48]
# [0 1]
# [1 0]
# ['never' 'No Info' 'current' 'former' 'ever' 'not current']
# [25.19 27.32 23.45 ... 59.42 44.39 60.52]
# [6.6 5.7 5.  4.8 6.5 6.1 6.  5.8 3.5 6.2 4.  4.5 9.  7.  8.8 8.2 7.5 6.8]
# [140  80 158 155  85 200 145 100 130 160 126 159  90 260 220 300 280 240]
# [0 1]

# %% [markdown]
# # Segreagate the Numerical and Categorical columns

# %%
[feature for feature in df.columns]
# Out:
# ['gender',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'smoking_history',
#  'bmi',
#  'HbA1c_level',
#  'blood_glucose_level',
#  'diabetes']

# %%
# Numerical columns

num_columns = [feature for feature in df.columns if df[feature].dtypes!='objects']
print(" Numerical columns :", len(num_columns))
print((num_columns))
# Out:
#  Numerical columns : 9
# ['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes']

# %%
# Categorical Columns

cat_columns = [feature for feature in df.columns if df[feature].dtype=='objects']
print(" Categorical columns : ", len(cat_columns))
print((cat_columns))
# Out:
#  Categorical columns :  0
# []

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df['gender'].value_counts()
# Out:
# Female    56161
# Male      39967
# Other        18
# Name: gender, dtype: int64

# %%
sns.displot(df['gender'])

# %%
sns.histplot(df["age"])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.countplot(df['gender'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
# check the gender and age quality

plt.figure.figsize=(25,20)
diabetes = pd.crosstab(df['gender'],df['age'])
diabetes.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
sns.displot(df['diabetes'])

# %%
# check the smoking history of people

sns.displot(df['smoking_history'])

# %%
# check the how many gender are belong to the smoking history

plt.figure(figsize=(18,15))
gender = pd.crosstab(df['gender'] , df['smoking_history'])
gender.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %% [markdown]
# * it is indicated the  more female are belong to the never smoking_history and

# %%
# check the diabetes of gender

plt.figure(figsize=(18,15))
diabetes = pd.crosstab(df['gender'] , df['diabetes'])
diabetes.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %% [markdown]
# * it is indiacte the more female are not belong to the diabetes and only 5000 are female are belong to the diabetes
# * more male person not belong to the diabetes and only less than 5000 male are belong to the diabetes

# %%
sns.displot(df['bmi'])

# %%
sns.displot(df['blood_glucose_level'])

# %%
sns.histplot(df['hypertension'])
# Out:
# <AxesSubplot:xlabel='hypertension', ylabel='Count'>

# %%
sns.histplot(df['heart_disease'])
# Out:
# <AxesSubplot:xlabel='heart_disease', ylabel='Count'>

# %%
sns.displot(df['HbA1c_level'])

# %%
# check the how many gender are belong to hypertension

plt.figure(figsize=(15,12))
gender = pd.crosstab(df['gender'] , df['hypertension'])
gender.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
# check the which age of more hypertension

plt.figure(figsize=(20,15))
age = pd.crosstab(df['hypertension'],df['age'])
age.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='hypertension'>

# %%
# gender 

labels = ['Female', 'Male', 'Other']
values = df['gender'].value_counts().values

plt.style.use('fivethirtyeight')
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
sns.countplot(x=df['gender'], data=df)
plt.subplot(1, 2, 2)
plt.pie(values, labels=labels, autopct='%1.1f%%')

plt.savefig('FirstImage')
plt.show()

# %%
# checking the status of smoking_history


labels = ['never', 'No Info', 'former', 'current', 'not current', 'ever']
values = df['smoking_history'].value_counts().values

plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
sns.countplot(x=df['smoking_history'], data=df)
plt.subplot(1, 2, 2)
plt.pie(values, labels=labels, autopct='%1.1f%%')

plt.savefig('Image')
plt.show()

# %% [markdown]
# # Statistical Based Analysis

# %%
df.describe()
# Out:
#                 age  hypertension  heart_disease           bmi   HbA1c_level  \
# count  96146.000000  96146.000000   96146.000000  96146.000000  96146.000000
# mean      41.794326      0.077601       0.040803     27.321461      5.532609
# std       22.462948      0.267544       0.197833      6.767716      1.073232
# min        0.080000      0.000000       0.000000     10.010000      3.500000
# 25%       24.000000      0.000000       0.000000     23.400000      4.800000
# 50%       43.000000      0.000000       0.000000     27.320000      5.800000
# 75%       59.000000      0.000000       0.000000     29.860000      6.200000
# max       80.000000      1.000000       1.000000     95.690000      9.000000
#
#        blood_glucose_level      diabetes
# count         96146.000000  96146.000000
# mean            138.218231      0.088220
# std              40.909771      0.283616
# min              80.000000      0.000000
# 25%             100.000000      0.000000
# ...

# %%
df.describe().T
# Out:
#                        count        mean        std    min    25%     50%  \
# age                  96146.0   41.794326  22.462948   0.08   24.0   43.00
# hypertension         96146.0    0.077601   0.267544   0.00    0.0    0.00
# heart_disease        96146.0    0.040803   0.197833   0.00    0.0    0.00
# bmi                  96146.0   27.321461   6.767716  10.01   23.4   27.32
# HbA1c_level          96146.0    5.532609   1.073232   3.50    4.8    5.80
# blood_glucose_level  96146.0  138.218231  40.909771  80.00  100.0  140.00
# diabetes             96146.0    0.088220   0.283616   0.00    0.0    0.00
#
#                         75%     max
# age                   59.00   80.00
# hypertension           0.00    1.00
# heart_disease          0.00    1.00
# bmi                   29.86   95.69
# HbA1c_level            6.20    9.00
# blood_glucose_level  159.00  300.00
# diabetes               0.00    1.00

# %%
# check the summary of statistics categorical columns

df.describe(include='object')
# Out:
#         gender smoking_history
# count    96146           96146
# unique       3               6
# top     Female           never
# freq     56161           34398

# %%
# check the correlation 
df.corr()
# Out:
#                           age  hypertension  heart_disease       bmi  \
# age                  1.000000      0.257305       0.238451  0.344797
# hypertension         0.257305      1.000000       0.119982  0.148111
# heart_disease        0.238451      0.119982       1.000000  0.061376
# bmi                  0.344797      0.148111       0.061376  1.000000
# HbA1c_level          0.106719      0.081441       0.068140  0.084423
# blood_glucose_level  0.114317      0.084834       0.070832  0.092543
# diabetes             0.264927      0.195710       0.170711  0.214932
#
#                      HbA1c_level  blood_glucose_level  diabetes
# age                     0.106719             0.114317  0.264927
# hypertension            0.081441             0.084834  0.195710
# heart_disease           0.068140             0.070832  0.170711
# bmi                     0.084423             0.092543  0.214932
# HbA1c_level             1.000000             0.171615  0.406408
# ...

# %%
# check the covariance 

df.cov()
# Out:
#                             age  hypertension  heart_disease        bmi  \
# age                  504.584014      1.546357       1.059658  52.416958
# hypertension           1.546357      0.071580       0.006351   0.268178
# heart_disease          1.059658      0.006351       0.039138   0.082175
# bmi                   52.416958      0.268178       0.082175  45.801974
# HbA1c_level            2.572780      0.023385       0.014467   0.613190
# blood_glucose_level  105.051869      0.928522       0.573268  25.621901
# diabetes               1.687810      0.014850       0.009578   0.412547
#
#                      HbA1c_level  blood_glucose_level  diabetes
# age                     2.572780           105.051869  1.687810
# hypertension            0.023385             0.928522  0.014850
# heart_disease           0.014467             0.573268  0.009578
# bmi                     0.613190            25.621901  0.412547
# HbA1c_level             1.151827             7.534885  0.123705
# ...

# %%
# check the skewness
df.skew()
# Out:
# age                   -0.062445
# hypertension           3.157676
# heart_disease          4.642359
# bmi                    1.023751
# HbA1c_level           -0.054463
# blood_glucose_level    0.836489
# diabetes               2.903845
# dtype: float64

# %%
# check the kurotesis

df.kurt()
# Out:
# age                    -1.004416
# hypertension            7.971082
# heart_disease          19.551902
# bmi                     3.271554
# HbA1c_level             0.239007
# blood_glucose_level     1.758476
# diabetes                6.432451
# dtype: float64

# %%
# check the quantile

df.quantile()
# Out:
# age                     43.00
# hypertension             0.00
# heart_disease            0.00
# bmi                     27.32
# HbA1c_level              5.80
# blood_glucose_level    140.00
# diabetes                 0.00
# Name: 0.5, dtype: float64

# %%
# check the min value 
df.min()
# Out:
# gender                  Female
# age                       0.08
# hypertension                 0
# heart_disease                0
# smoking_history        No Info
# bmi                      10.01
# HbA1c_level                3.5
# blood_glucose_level         80
# diabetes                     0
# dtype: object

# %%
# check the max value
df.max()
# Out:
# gender                       Other
# age                           80.0
# hypertension                     1
# heart_disease                    1
# smoking_history        not current
# bmi                          95.69
# HbA1c_level                    9.0
# blood_glucose_level            300
# diabetes                         1
# dtype: object

# %%
# check the heat map
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pair plot

# %%
sns.pairplot(df , diag_kind = 'kde')

# %% [markdown]
# # Box plot

# %%
plt.figure(figsize=(15,12))
sns.boxplot(data=df , orient = 'v')
# Out:
# <AxesSubplot:>

# %% [markdown]
# * it is indicated the  two columns are bmi and blood_glucose_level are outliers

# %% [markdown]
# # Handle the outliers

# %%
# bmi and blood_glucose_level

IQR = df['bmi'].quantile(0.75) - df['bmi'].quantile(0.25)
lower_fence = df['bmi'].quantile(0.25) - 1.5*IQR
upper_fence = df['bmi'].quantile(0.75) + 1.5*IQR

lower_fence , upper_fence
# Out:
# (13.709999999999997, 39.55)

# %%
df['bmi'] = np.where(df['bmi']>upper_fence , upper_fence , np.where(df['bmi']<lower_fence , lower_fence , df['bmi']))

# %%
sns.boxplot(df['bmi'])
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
# blood_glucose_level 

IQR = df['blood_glucose_level'].quantile(0.75) - df['blood_glucose_level'].quantile(0.25)
lower_fence = df['blood_glucose_level'].quantile(0.25) - 1.5*IQR
upper_fence = df['blood_glucose_level'].quantile(0.75) + 1.5*IQR


lower_fence , upper_fence
# Out:
# (11.5, 247.5)

# %%
df['blood_glucose_level'] = np.where(df['blood_glucose_level']>upper_fence , upper_fence , np.where(df['blood_glucose_level']<lower_fence , lower_fence , df['blood_glucose_level']))

# %%
sns.boxplot(df['blood_glucose_level'])
# Out:
# <AxesSubplot:xlabel='blood_glucose_level'>

# %% [markdown]
# # Handle Categorical variable

# %%
df.gender.value_counts()
# Out:
# Female    56161
# Male      39967
# Other        18
# Name: gender, dtype: int64

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['gender'] = le.fit_transform(df['gender'])

# %%
df['smoking_history'] = le.fit_transform(df['smoking_history'])

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0             0              1                4  25.19
# 1       0  54.0             0              0                0  27.32
# 2       1  28.0             0              0                4  27.32
# 3       0  36.0             0              0                1  23.45
# 4       1  76.0             1              1                1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                140.0         0
# 1          6.6                 80.0         0
# 2          5.7                158.0         0
# 3          5.0                155.0         0
# 4          4.8                155.0         0

# %% [markdown]
# # Train Test Split

# %% [markdown]
# * Split dataframe X and Y
#
# * X is independent data and y is dependent data (diabetes)

# %%
df.shape
# Out:
# (96146, 9)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['diabetes'],axis=1)
y = df['diabetes']

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y, test_size=0.30 , random_state=40)

# %%
X_train.shape , y_train.shape
# Out:
# ((67302, 8), (67302,))

# %%
X_test.shape , y_test.shape
# Out:
# ((28844, 8), (28844,))

# %% [markdown]
# # check the Imblance data

# %%
sns.countplot(df['diabetes'])
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='count'>

# %% [markdown]
# * it is indicated the imblance data

# %%
sns.distplot(df['diabetes'])
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='Density'>

# %% [markdown]
# # handle the imblance data

# %%
from imblearn.over_sampling import SMOTE

# %%
sns.countplot(df['diabetes'])
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='count'>

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_train
# Out:
# array([[ 1.18366897, -1.63902374, -0.29054126, ...,  0.04727221,
#         -1.89477435,  0.55683667],
#        [-0.84328358, -0.39091622, -0.29054126, ...,  0.27040695,
#         -0.68186335, -0.97186644],
#        [-0.84328358,  0.81261604, -0.29054126, ...,  0.04727221,
#         -1.89477435, -0.97186644],
#        ...,
#        [ 1.18366897,  0.76804077, -0.29054126, ..., -0.78779266,
#         -0.96176589,  0.55683667],
#        [-0.84328358,  0.99091711,  3.44185193, ...,  0.37690308,
#          0.62434849,  0.55683667],
#        [-0.84328358,  1.34751926, -0.29054126, ...,  0.04727221,
#         -1.89477435,  0.53092645]])

# %%
X_test = scaler.transform(X_test)
X_test
# Out:
# array([[ 1.18366897,  1.70412141, -0.29054126, ..., -0.3094053 ,
#         -0.49526166,  1.61915578],
#        [-0.84328358, -0.12346461, -0.29054126, ...,  1.75290067,
#          0.90425103, -0.19455977],
#        [-0.84328358, -0.97039471, -0.29054126, ...,  0.04727221,
#          0.2511451 ,  0.45319578],
#        ...,
#        [-0.84328358,  0.99091711, -0.29054126, ...,  0.04727221,
#          1.18415356,  0.19409356],
#        [-0.84328358, -1.05954525, -0.29054126, ...,  0.04727221,
#          0.99755187,  0.58274689],
#        [ 1.18366897, -0.52464202, -0.29054126, ...,  1.31508325,
#         -0.96176589,  0.55683667]])

# %%
y_test
# Out:
# 55800    0
# 65828    0
# 52596    0
# 70146    0
# 71504    0
#         ..
# 15731    0
# 18324    0
# 38751    1
# 83054    0
# 99747    0
# Name: diabetes, Length: 28844, dtype: int64

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg
# Out:
# LogisticRegression()

# %%
log_reg.fit(X_train , y_train)
log_reg.score(X_train,y_train)
# Out:
# 0.957802145552881

# %%
y_pred = log_reg.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from  sklearn.metrics import accuracy_score
acc_score = accuracy_score(y_pred , y_test)
acc_score
# Out:
# 0.9574261544862016

# %% [markdown]
# # 2. Support Vector Classification

# %%
from sklearn.svm import SVC
svc = SVC()
svc
# Out:
# SVC()

# %%
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
svc.score(X_train,y_train)
# Out:
# 0.9630471605598645

# %%
y_predict = svc.predict(X_test)
y_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_predict,y_test)
# Out:
# 0.962799889058383

# %% [markdown]
# # 3 . Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()
decision_tree
# Out:
# DecisionTreeClassifier()

# %%
decision_tree.fit(X_train,y_train)
decision_tree.score(X_train,y_train)
# Out:
# 0.9990639208344477

# %%
#from sklearn import tree
#import matplotlib.pyplot as plt
#fig = plt.figure(figsize=(20,14))
#tree.plot_tree(decision_tree,filled=True)

# %%
fig.savefig('Decision Tree Classifier')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [95], in <cell line: 1>()
# ----> 1 fig.savefig('Decision Tree Classifier')
#
# NameError: name 'fig' is not defined

# %%
y_predict = decision_tree.predict(X_test)
y_predict
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_predict,y_test)
# Out:
# 0.9489321869366246

# %% [markdown]
# # 4. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier()
rf_classifier
# Out:
# RandomForestClassifier()

# %%
rf_classifier.fit(X_train , y_train)
rf_classifier.score(X_train , y_train)
# Out:
# 0.9989896288371817

# %%
y_pred_rf_class = rf_classifier.predict(X_test)
y_pred_rf_class
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred_rf_class , y_test)
# Out:
# 0.9681736236305644

# %% [markdown]
# # 5. Extra Trees Classifiers

# %%
from sklearn.ensemble import ExtraTreesClassifier
et_classifier = ExtraTreesClassifier()
et_classifier
# Out:
# ExtraTreesClassifier()

# %%
et_classifier.fit(X_train , y_train)
# Out:
# ExtraTreesClassifier()

# %%
y_predict_et_class = et_classifier.predict(X_test)
y_predict_et_class
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

et_acc = accuracy_score(y_test , y_predict_et_class)
et_acc
# Out:
# 0.9652267369296907

# %% [markdown]
# # 6 . Ada Boosting  Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier()
ada
# Out:
# AdaBoostClassifier()

# %%
ada.fit(X_train , y_train)
# Out:
# AdaBoostClassifier()

# %%
y_predict_ada = ada.predict(X_test)
y_predict_ada
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict_ada)
# Out:
# 0.9704271252253501

# %% [markdown]
# # 7. Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
model_gbm = GradientBoostingClassifier()
model_gbm
# Out:
# GradientBoostingClassifier()

# %%
model_gbm.fit(X_train , y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_predict_gbm = model_gbm.predict(X_test)
y_predict_gbm
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_predict_gbm)
# Out:
# 0.9707738177783941

# %% [markdown]
# # 8.  Extreme Gradient Boosting Classifier Model  (XGB)

# %%
import xgboost
model_xgb = xgboost.XGBClassifier()
model_xgb.fit(X_train , y_train)
y_predict_xgb = model_xgb.predict(X_test)

# %%
model_xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred_xgb = model_xgb.predict(X_test)

# %%
accuracy_score(y_test,y_pred_xgb)
# Out:
# 0.9699070863957843

# %% [markdown]
# # 2. Method Model Building

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
y_pred_log_reg = log_reg.predict(X_test)
y_pred_log_reg
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score , classification_report, ConfusionMatrixDisplay,precision_score,recall_score,f1_score

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "Support Vector Classifier": SVC(),
    "Decision Tree Classifier ": DecisionTreeClassifier(),
    "Random Forest Classifier ": RandomForestClassifier(),
    "Ada Boost Classifier ": AdaBoostClassifier(),
    " Navie Bayes" : GaussianNB()    
}

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,y_train)
    
    # prediction
    
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    # training set performance
    model_train_accuracy = accuracy_score(y_train,y_train_pred)
    model_train_f1 = f1_score(y_train,y_train_pred)
    model_train_precision = precision_score(y_train,y_train_pred)
    model_train_recall = recall_score(y_train,y_train_pred)
    
    
    
    # Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred) 
    model_test_f1 = f1_score(y_test, y_test_pred)
    model_test_precision = precision_score(y_test, y_test_pred) 
    model_test_recall = recall_score(y_test, y_test_pred) 


    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))
    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    
    print('----------------------------------')
    
    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    
    print("="*20)
    print('\n')
# Out:
# Logistic Regression
# Model performance for Training set
# - Accuracy: 0.9578
# - F1 score: 0.7214
# - Precision: 0.8561
# - Recall: 0.6233
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9574
# - F1 score: 0.7267
# - Precision: 0.8550
# - Recall: 0.6320
# ...
#
#
# Support Vector Classifier
# Model performance for Training set
# - Accuracy: 0.9630
# - F1 score: 0.7358
# - Precision: 0.9849
# - Recall: 0.5873
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9628
# - F1 score: 0.7414
# - Precision: 0.9827
# - Recall: 0.5952
# ...
#
#
# Decision Tree Classifier
# Model performance for Training set
# - Accuracy: 0.9991
# - F1 score: 0.9946
# - Precision: 1.0000
# - Recall: 0.9893
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9488
# - F1 score: 0.7216
# - Precision: 0.7038
# - Recall: 0.7403
# ...
#
#
# Random Forest Classifier
# Model performance for Training set
# - Accuracy: 0.9990
# ...
